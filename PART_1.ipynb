# %% [markdown]
# ASSIGNMENT -
# Part 1 -
# Get name, address, open times for Village from Yelp API.

# %%
import requests
from bs4 import BeautifulSoup
import re

class RestaurantMenuScraper:
    def __init__(self, yelp_api_key):
        self.YELP_API_KEY = yelp_api_key
        self.HEADERS = {
            "Authorization": f"Bearer {self.YELP_API_KEY}",
            "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36"
        }

    def get_restaurant_details(self, restaurant_name, location):
        """
        Retrieve restaurant details from Yelp API
        
        :param restaurant_name: Name of the restaurant
        :param location: Location to search
        :return: Detailed restaurant information
        """
        search_url = "https://api.yelp.com/v3/businesses/search"
        params = {
            "term": restaurant_name,
            "location": location,
            "limit": 1
        }
        
        try:
            response = requests.get(search_url, headers=self.HEADERS, params=params)
            response.raise_for_status()
            data = response.json()
            
            if "businesses" in data and len(data["businesses"]) > 0:
                business = data["businesses"][0]
                business_id = business["id"]
                
                # Fetch detailed information
                details_url = f"https://api.yelp.com/v3/businesses/{business_id}"
                details_response = requests.get(details_url, headers=self.HEADERS)
                details_response.raise_for_status()
                details_data = details_response.json()
                
                return details_data
            else:
                print(f"No data found for {restaurant_name}.")
                return None
        
        except requests.exceptions.RequestException as e:
            print(f"Error retrieving restaurant details: {e}")
            return None

    def extract_open_times(self, hours_data):
        # List of days in a standard week
        days = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
        formatted_times = {}
        
        # Initialize all days as "Closed"
        for day in days:
            formatted_times[day] = "Closed"
        
        if hours_data:
            # Loop through each entry in 'hours_data'
            for period in hours_data:
                # Check if 'open' field exists in the current period
                if 'open' in period:
                    for time_slot in period['open']:
                        # Get the corresponding day from the index in the 'days' list
                        day = days[time_slot['day']]
                        
                        # Extract start and end times
                        start_time = f"{time_slot['start'][:2]}:{time_slot['start'][2:]}"
                        end_time = f"{time_slot['end'][:2]}:{time_slot['end'][2:]}"
                        
                        # Format and assign the opening times
                        if formatted_times[day] == "Closed":
                            formatted_times[day] = f"{start_time} - {end_time}"
                        else:
                            formatted_times[day] += f", {start_time} - {end_time}"
    
        return formatted_times


def main():
    # Yelp API Key
    YELP_API_KEY = "-He3gbhB7wZ21g2U0nXCiyVdXkUZiYx" # Replace with your Yelp API Key
    
    # Initialize scraper
    scraper = RestaurantMenuScraper(YELP_API_KEY)
    
    # Get restaurant details
    restaurant_details = scraper.get_restaurant_details(
        "Village - The Soul of India", 
        "Hicksville"
    )
    
    if restaurant_details:
        # Extract and print basic information
        print("Restaurant Details:")
        print("Name:", restaurant_details["name"])
        print("Address:", ", ".join(restaurant_details["location"]["display_address"]))
        
        # Parse and print open times
        open_times = scraper.extract_open_times(restaurant_details.get('hours', []))
        print("\nOpen Times:")
        for day, times in open_times.items():
            print(f"{day}: {times}")

if __name__ == "__main__":
    main()
# Out:
# Restaurant Details:
# Name: Village the soul of india
# Address: 11 West Marie St, Hicksville, NY 11801
#
# Open Times:
# Monday: 11:00 - 15:00, 17:00 - 22:00
# Tuesday: Closed
# Wednesday: 11:00 - 15:00, 17:00 - 22:00
# Thursday: 11:00 - 15:00, 17:00 - 22:00
# Friday: 11:00 - 15:00, 17:00 - 22:00
# Saturday: 11:30 - 22:00
# Sunday: 11:30 - 22:00

# %% [markdown]
#  Print menu items, & prices for Village from Yelp API. Also, save a village_menu.csv file

# %%
import csv
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.action_chains import ActionChains

# Setup WebDriver
options = webdriver.ChromeOptions()
options.add_argument('--headless')  # Run headlessly (without a UI)
driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=options)

# URL to scrape
url = 'https://www.yelp.com/menu/village-the-soul-of-india-hicksville'
driver.get(url)

# Optionally, you can wait for JavaScript to load the page if needed
driver.implicitly_wait(5)

# Extract Menu Item Names
menu_items = driver.find_elements(By.CSS_SELECTOR, '.menu-item-details h4')

# Extract Menu Descriptions
descriptions = driver.find_elements(By.CSS_SELECTOR, '.menu-item-details .menu-item-details-description')

# Extract Prices
prices = driver.find_elements(By.CSS_SELECTOR, '.menu-item-price-amount')

# Prepare data to be written to CSV and print to console
menu_data = []
for item, desc, price in zip(menu_items, descriptions, prices):
    item_data = [item.text, desc.text, price.text]
    menu_data.append(item_data)
    # Print extracted data
    print(f"Item: {item.text}")
    print(f"Description: {desc.text}")
    print(f"Price: {price.text}")
    print('---')

# Save data to CSV file
with open('village_menu.csv', mode='w', newline='') as file:
    writer = csv.writer(file)
    writer.writerow(['Item', 'Description', 'Price'])  # Write header
    writer.writerows(menu_data)  # Write the menu data

# Close the browser after scraping
driver.quit()

print("Data has been saved to 'village_menu.csv'.")
# Out:
# Item: Medu Vada
# Description: Lentil flour donuts.
# Price: $6.00
# ---
# Item: Medu Vada in Sambar Bowl
# Description: Lentil flour donuts smothered with sambar.
# Price: $6.99
# ---
# Item: Medu Vada in Rasam Bowl
# Description: Lentil flour donuts smothered with Rasam soup.
# Price: $6.99
# ---
# Item: Combo
# Description: Rice cake and lentil donut.
# Price: $5.99
# ---
# Item: Combo in Sambar Bowl
# Description: Idly and Vada.
# Price: $6.99
# ---
# Item: Masala Vada
# Description: Crispy Chenna Dal mixed with spiced and fried.
# Price: $7.45
# ---
# Item: Dahi Vada
# Description: Lentil donut soaked in sweet yogurt.
# Price: $8.95
# ---
# Item: Batata Vada
# Description: Mashed potato spices and fried with chickpeas flour.
# Price: $6.00
# ---
# Item: Mysore Bonda
# Description: Lentil balls spices and cashew fried.
# Price: $6.00
# ---
# Item: Chennai Pakkoda
# Description: Onions and Chenna Dal spices fried.
# Price: $6.00
# ---
# Item: Spring Rolls
# Description: Vegetables stuffed platter.
# Price: $7.45
# ---
# Item: Paneer Pakkoda
# Description: Cottage cheese deep-fried with spices.
# Price: $8.95
# ---
# Item: Samosa
# Description: Spiced potato with green peas dumplings.
# Price: $6.00
# ---
# Item: Aloo Tikki
# Description: Mashed potato with spiced fried.
# Price: $6.00
# ---
# Item: Chilly Pakora
# Description: South Indian spiced lentil soup.
# Price: $6.00
# ---
# Item: Tomato Soup
# Description: Lentil based vegetable soup.
# Price: $7.45
# ---
# Item: Vegetables Manchow Soup
# Description: Lentil thick soup with pepper and spices.
# Price: $7.45
# ---
# Item: Rasam
# Description: Mixed vegetables soup.
# Price: $7.45
# ---
# Item: Sambar
# Description: Simple chopped salad with onions, tomato, and cucumber chips.
# Price: $7.45
# ---
# Item: Mulligatawny Soup
# Description: Dressing with lettuce, tomato, cucumber, and carrots.
# Price: $7.45
# ---
# Item: Garden Soup
# Description: A Savary rice cake from Indian subcontinent.
# Price: $7.45
# ---
# Item: Katchumbar Salad
# Description: Rice cakes sauteed with Indian spices and herbs.
# Price: $7.45
# ---
# Item: Garden Salad
# Description: Small cocktail idly.
# Price: $7.45
# ---
# Item: Idly
# Description: Rice cakes fried with spices and onions.
# Price: $7.45
# ---
# Item: Masala Idly
# Description: Rice pancakes spiced with dry Channa Daal powder.
# Price: $9.95
# ---
# Item: Mini Idly
# Description: Rice cakes cooked with onion and bell peppering Chinese chilli sauce.
# Price: $7.45
# ---
# Item: Ghee Fried Idly
# Description: Rice cakes smothered with sambar.
# Price: $9.95
# ---
# Item: Podi Idly
# Description: Rice cakes smothered with rasam soup.
# Price: $8.95
# ---
# Item: Chilli Idly
# Description: Rice cakes soaked in sweet yogurt.
# Price: $9.95
# ---
# Item: Idly in Sambar Bow
# Description: Crispy rice puffs topped with onions, tomato chutney and spices.
# Price: $8.95
# ---
# Item: Idly Rasam Bowl
# Description: Samosas topped with chickpeas, onions, tomato, yogurt, chutney and spices.
# Price: $8.95
# ---
# Item: Dami Idly
# Description: Aloo Tikkis topped with chickpeas, onion, tomato, yogurt, chutney, and spices.
# Price: $7.45
# ---
# Item: Bhel Puri
# Description: Crispy pooris topped chana, onions, tomato, Chutney yogurt, chutney, and spices.
# Price: $8.95
# ---
# Item: Samosa Chat
# Description: Soft lentil balls dipped in spiced yogurt topped with chutney.
# Price: $8.95
# ---
# Item: Aloo Tikki Chat
# Description: Chickpeas in yogurt, tamarind, cilantro, onion, tomato sauce.
# Price: $9.95
# ---
# Item: Papdee Chat
# Description: Potato in a yogurt, tamarind, cilantro, onion, tomato sauce.
# Price: $8.95
# ---
# Item: Dahi Bhalla
# Description: Potato in a yogurt, tamarind, cilantro, onion, tomato sauce.
# Price: $8.95
# ---
# Item: Channa Chat
# Description: A spicy curry of mixed vegetables (Bhaji) cooked in a special blend of spices and served with soft buttered pav.
# Price: $8.95
# ---
# Item: Aloo Chat
# Description: Vegetables tossed in home style sauce.
# Price: $8.95
# ---
# Item: Vadda Pav
# Description: Vegetables tossed in home style sauce.
# Price: $8.95
# ---
# Item: Pav Bhaji
# Description: Cottage cheese tossed in our home-made chilli sauce.
# Price: $13.75
# ---
# Item: Vegetables Manchurian
# Description: Cauliflower tossed in home style sauce.
# Price: $12.95
# ---
# Item: Baby Corn Chilly Manchurian
# Description: Mushroom tossed with onion and ball pepper in Chinese sauce.
# Price: $13.75
# ---
# Item: Chilly Paneer Dry
# Description: Sliced potato tossed in dried red chilli and onions.
# Price: $13.75
# ---
# Item: Gobi Manchurian Dry
# Description: Onion and cauliflower tossed with home-made sauce and honey.
# Price: $12.95
# ---
# Item: Chilli Mushroom
# Description: Cauliflower sauteed with chilli sauces.
# Price: $12.95
# ---
# Item: Crispy Chilli Potato
# Description: Indian-style vegetable hakka noodles have vegetables like onion, cabbage, bell pepper, and carrots.
# Price: $12.95
# ---
# Item: Honey Garlic Gobi
# Description: Cooked rice fried with vegetables and spices.
# Price: $12.95
# ---
# Item: Gobi Lasuni
# Description: Topped with noodles, dosa batter, cabbage, capsicum, paneer, peas, lemon juice and some common spices.
# Price: $12.95
# ---
# Item: Vegetables Hakka Noodles
# Description: Thin rice crepe.
# Price: $13.75
# ---
# Item: Vegetables Fried Rice
# Description: Soft thick rice crepe.
# Price: $12.95
# ---
# Item: Chinese Dosa
# Description: Crepe with mashed potato spices.
# Price: $14.95
# ---
# Item: Sada Dosa
# Description: Crepe cooked with butter.
# Price: $11.95
# ---
# Item: Set Dosa
# Description: Creape cooked with butter and potato.
# Price: $11.95
# ---
# Item: Masala Dosa
# Description: Clarified butter crepe.
# Price: $12.95
# ---
# Item: Butter Sada Dosa
# Description: Thin layer crepe.
# Price: $11.95
# ---
# Item: Butter Masala Dosa
# Description: Spicy red crepe. Spicy.
# Price: $13.75
# ---
# Item: Ghee Roast Masala
# Description: Spicy red crepe. Spicy.
# Price: $13.75
# ---
# Item: Paper Roast Dosa
# Description: Crepe with chana dal. Red chilli and spices.
# Price: $12.95
# ---
# Item: Mysore Sada Dosa
# Description: Crepe very spicy with chana dal. Red chilli and spices fried with potato. Spicy.
# Price: $12.95
# ---
# Item: Masala Dosa
# Description: Crepe cooked with onion and chilli.
# Price: $12.95
# ---
# Item: Podi Masala Dosa
# Description: Crepe topped with chopped onions and green chilis.
# Price: $12.95
# ---
# Item: Gun Powder Masala Dosa
# Description: Crepe cooked with mushroom and spiced potatoes.
# Price: $12.95
# ---
# Item: Onion Chilli Sada Dosa
# Description: Paneer, potato, onion, tomato, chillis.
# Price: $12.95
# ---
# Item: Onion Chilli Masala Dosa
# Description: Crepe cooked with Cottage cheese and potato.
# Price: $12.95
# ---
# Item: Chef Special Sampler Dosa 5 Kinds
# Description: Crepe cooked with Cottage cheese, onions, bell pepper.
# Price: $24.95
# ---
# Item: Chocolate Dosa
# Description: Crepe cooked with spinach and potato spices.
# Price: $13.75
# ---
# Item: Chocolate Dosa in Jain Fillings
# Description: Crepe cooked with cheddar cheese and spices.
# Price: $13.75
# ---
# Item: Mushroom Masala Dosa
# Description: Crepe cooked with cheddar cheese.
# Price: $13.75
# ---
# Item: Jaipur Dosa
# Description: Crepe cooked with cheddar cheese.
# Price: $14.95
# ---
# Item: Paneer Masala Dosa
# Description: Crepe cooked with cabbage, onions, ball pepper, and potato.
# Price: $14.95
# ---
# Item: Paneer Bhurji Dosa
# Description: Crepe rolled and filled with potato and spices.
# Price: $16.00
# ---
# Item: Spinach Masala Dosa
# Description: Crepe rolled and filled with potato and spices.
# Price: $14.95
# ---
# Item: Cheese Onion Chili Masala Dosa
# Description: Crepe made spicy filled with Cottage cheese and potato.
# Price: $14.95
# ---
# Item: Cheese Masala Dosa
# Description: Lentil and rice flour pancake.
# Price: $13.75
# ---
# Item: Cheese Masala Sada
# Description: Thick rice pancakes topped with vegetables looks like pizza no cheese.
# Price: $13.75
# ---
# Item: Spring Masala Dosa
# Description: Topped with onion and green chilli.
# Price: $14.95
# ---
# Item: Pondicherry Masala Dosa
# Description: Topped with onion and sliced mushroom.
# Price: $14.95
# ---
# Item: Cheese Pondicherry
# Description: Topped with chilli, tomato and garlic.
# Price: $14.95
# ---
# Item: Paneer Pondicherry Dosa
# Description: Topped with Dosa Podi and gunpowder.
# Price: $14.95
# ---
# Item: Mushroom, Paneer, Spinach Masala Dosa
# Description: Topped with onion, tomato, peas, carrots, and cheese.
# Price: $15.00
# ---
# Item: Plain Uthappam
# Description: Topped with sliced paneer.
# Price: $11.95
# ---
# Item: Vegetable Uthappam
# Description: Semolina crepe only.
# Price: $12.95
# ---
# Item: Onion Chilli Uthappam
# Description: Semolina crepe with mashed spiced potato.
# Price: $13.75
# ---
# Item: Mushroom Uthappam
# Description: Semolina crepe made spicy with house spices.
# Price: $13.75
# ---
# Item: Onion Chilli Garlic Uthappam
# Description: Semolina crepe made with onion chilli and house spices.
# Price: $13.75
# ---
# Item: Gun Powder Uthappam
# Description: Rava Dosa filled with cheese, onions and seasoned potato filling.
# Price: $13.75
# ---
# Item: Vegetable Cheese Uthappam
# Description: Rava Dosa filled with coconut.
# Price: $14.95
# ---
# Item: Paneer Uthappam
# Description: Mix veg cooked with paneer, cream, and cheese.
# Price: $14.95
# ---
# Item: Custom Uthappam
# Description: Dosa cooked and rolled with vegetables.
# Price: $16.00
# ---
# Item: Masala Uthappam
# Description: Rava or regular. Dosa cooked with garlic, chilli, onion and cheese.
# Price: $18.00
# ---
# Item: Veg Uthappam
# Description: Potato and creamed spinach, green peas, cauliflower mildly spiced tomato sauce.
# Price: $13.75
# ---
# Item: Rava Sada Dosa
# Description: Potato and creamed spinach, green peas, cauliflower mildly spiced tomato sauce.
# Price: $14.95
# ---
# Item: Onion Rava Masala Dosa
# Description: Potato and creamed spinach, green peas, cauliflower mildly spiced tomato sauce.
# Price: $14.95
# ---
# Item: Onion Mysore Rava Masala Dosa
# Description: Fresh cauliflower cooked in onion base sauce.
# Price: $16.00
# ---
# Item: Madras Rava Masala Dosa
# Description: Fresh cauliflower cooked in onion base sauce.
# Price: $16.00
# ---
# Item: Cheese Onion Rava Masala Dosa
# Description: Chickpea, onion and masala spices.
# Price: $16.00
# ---
# Item: Coconut Rava Masala Dosa
# Description: Spinach and chickpeas cooked with spices.
# Price: $14.95
# ---
# Item: Rava Chilli Gun Powder Masala Dosa
# Description: Yellow lentils cooked and spices with your choice of spinach or no spinach.
# Price: $16.00
# ---
# Item: Rava Chilli Gun Powder Masala Dosa in Jain Fillings
# Description: Yellow lentils cooked and spices.
# Price: $16.00
# ---
# Item: Fresh Spring Onion Rava Masala Dosa
# Description: Green peas and homemade cheese cooked with spices.
# Price: $15.00
# ---
# Item: Matka Dosa
# Description: Spinach and homemade cheese cooked with spices.
# Price: $18.00
# ---
# Item: Jinni Dosa
# Description: Cooked spinach studded with cubes of fried paneer cheese.
# Price: $18.00
# ---
# Item: Village Special Dosa
# Description: Cubes of paneer and veggies marinated with yogurt and spices.
# Price: $18.00
# ---
# Item: Dal Makhni
# Description: Fresh cheese made by curdling milk with lemon.
# Price: $16.00
# ---
# Item: Aloo Gobi
# Description: Fresh methi leaves with green peas and creamy in a sweet, rich, and creamy curry.
# Price: $16.00
# ---
# Item: Mutter
# Description: Hot, spicy, flavorful button mushrooms and bell peppers.
# Price: $16.00
# ---
# Item: Palak
# Description: Paneer dumplings served with rich, creamy, and delicious gravy.
# Price: $16.00
# ---
# Item: Gobi Mutter
# Description: Scrambled paneer or Cottage cheese with a spiced mixture made of onions, ginger garlic paste.
# Price: $16.00
# ---
# Item: Aloo
# Description: Made with okra, whole and ground spices, onions and tomatoes.
# Price: $16.00
# ---
# Item: Chana Masala
# Description: Roasted eggplant (Brinjal) stars in this strong-flavoured curry.
# Price: $16.00
# ---
# Item: Chana Palak
# Description: Roasted eggplant mash cooked with spices.
# Price: $16.00
# ---
# Item: Daal Tadka
# Description: Rich luxurious curry dish made with mixed vegetables.
# Price: $16.00
# ---
# Item: Palak
# Description: Loaded with potatoes, tomatoes, carrots, peas, and green beans. Vegan.
# Price: $16.00
# ---
# Item: Mutter Paneer
# Description: Made with diced potatoes and eggplant that have been simmered in a spiced onion tomato.
# Price: $16.00
# ---
# Item: Palak Paneer
# Description: Coconut-based spicy curry with vegetables.
# Price: $16.00
# ---
# Item: Saag Paneer
# Description: Garlic. Gravy made with a tamarind based broth and loaded with lots of garlic.
# Price: $16.00
# ---
# Item: Paneer Tikka Masala
# Description: Eggplant. Gravy in which brinjal are stuffed with flavorful fresh ground masalas and sauteed in oil.
# Price: $16.00
# ---
# Item: Kadai Paneer
# Description: Okra. Tender okra. Lady's finger is simmered in tangy tamarind gravy.
# Price: $16.00
# ---
# Item: Methi Mutter Malai
# Description: Drumstick. A spicy and tangy tamarind based curry made with drumsticks.
# Price: $16.00
# ---
# Item: Kadai Mushroom
# Description: Idly, vada, dosa, uthappam, sambar, chutney, badam halwa.
# Price: $16.00
# ---
# Item: Malai Kofta
# Description: Sambar, rasam, kulambu, kootu avial, poriyal, pickle, yogurt, pappadam, rice, semiya payasam.
# Price: $16.00
# ---
# Item: Paneer Bhurji
# Description: Chole, daal, any paneer - rice, roti, pickle, raita, kheer, pappad.
# Price: $16.00
# ---
# Item: Bhindi Masala
# Description: Large puffed bread with spicy chickpeas.
# Price: $16.00
# ---
# Item: Eggplant Curry
# Description: Large puffed bread with spicy chickpeas.
# Price: $16.00
# ---
# Item: Baigan Bharta
# Description: Spiced aloo or sabji or bhaji with hints of coriander, ginger and other Indian spices.
# Price: $16.00
# ---
# Item: Nav Ratan Korma
# Description: Semolina with onion, cashews, chilli with Indian spices.
# Price: $16.00
# ---
# Item: Vegetable Korma
# Description: Rice, lentil, spices, nuts, and butter. Served with coconut chutney and sambar.
# Price: $16.00
# ---
# Item: Alu Baingan
# Description: Mixed vegetables cooked with coconut milk, yogurt and spices.
# Price: $16.00
# ---
# Item: Vegetables Kolhapur
# Description: Indian layerd bread chopped and cooked with Chineese sauce, ginger, and garlic.
# Price: $16.00
# ---
# Item: Malai Kofta Jain Style
# Description: Fried unleavened bread.
# Price: $16.00
# ---
# Item: Poondu Kulambu
# Description: Puffed up fried bread.
# Price: $16.00
# ---
# Item: Ennai Kathrika Kulambu
# Description: Onion paratha.
# Price: $16.00
# ---
# Item: Vendaikai Kulambu
# Description: Onion.
# Price: $14.95
# ---
# Item: Murungaikai Kulambu
# Description: Goodness of rice and vegetables that comes in layers.
# Price: $16.00
# ---
# Item: Chennal Thali
# Description: Basmati rice, vegetables, and spices.
# Price: $21.95
# ---
# Item: South Indian Thali
# Description: Riced cooked with lemon juice and spices.
# Price: $21.95
# ---
# Item: North Indian Thali
# Description: Rice cooked with tamarind and spices.
# Price: $21.95
# ---
# Item: Chole Bature
# Description: Rice, lentil and eggplant cooked with spices.
# Price: $16.00
# ---
# Item: Chole Poori
# Description: Rice cooked with tomato and spices.
# Price: $16.00
# ---
# Item: Poori Bhaji
# Description: Rice cooked with ground coconut and nuts.
# Price: $14.95
# ---
# Item: Poori Kurma
# Description: Rice smothered with yogurt.
# Price: $14.95
# ---
# Item: Uppma
# Description: Choice of soda.
# Price: $14.95
# ---
# Item: Pongal
# Description: Choice of flavor.
# Price: $14.95
# ---
# Item: Avial
# Description: Hot drink.
# Price: $14.95
# ---
# Item: Kutchu Chilli Paratha
# Description: Hot drink.
# Price: $14.95
# ---
# Item: Paneer Chettinad
# Description: Hot drink.
# Price: $16.00
# ---
# Item: Mix Vegetables Chettinad
# Description: Choice of flavor.
# Price: $16.00
# ---
# Item: Gobi Chettinad
# Description: Made with Club soda.
# Price: $16.00
# ---
# Item: Soya Chettinad
# Description: Made with Thums-up.
# Price: $16.00
# ---
# Data has been saved to 'village_menu.csv'.

# %% [markdown]
# Find latitude and longitude using API of Village

# %%
import requests

def get_coordinates_open_cage(address, api_key):
    """Get coordinates using OpenCage Geocoding API"""
    url = f'https://api.opencagedata.com/geocode/v1/json?q={address}&key={api_key}'
    response = requests.get(url)
    data = response.json()

    if data['status']['code'] == 200:
        lat = data['results'][0]['geometry']['lat']
        lng = data['results'][0]['geometry']['lng']
        return lat, lng
    else:
        print(f"Error: {data['status']['message']}")
        return None, None

# Example usage
api_key = 'abc'  # Replace with your OpenCage API key
address = "Village - The Soul of India, 11 West Marie St, Hicksville, NY 11801"
lat, lng = get_coordinates_open_cage(address, api_key)
print(f"Latitude: {lat}, Longitude: {lng}")
# Out:
# Latitude: 40.766876, Longitude: -73.523663

# %% [markdown]
# Get top-rated 5 restaurants in 2 km with similar menu items

# %%
import requests

def find_similar_restaurants(api_key, latitude, longitude, term="Indian Vegetarian", radius=2000, limit=5):
    """Fetch top-rated Vegetarian Indian restaurants near the specified coordinates."""
    url = "https://api.yelp.com/v3/businesses/search"
    headers = {"Authorization": f"Bearer {api_key}"}
    params = {
        "term": term,
        "latitude": latitude,
        "longitude": longitude,
        "radius": radius,
        "categories": "indian,dosa",
        "sort_by": "rating",
        "limit": limit + 1  # Include one extra to exclude the main restaurant
    }

    response = requests.get(url, headers=headers, params=params)
    data = response.json()

    # Filter out "Village - The Soul of India" and keep the top 5
    refined_restaurants = []
    for business in data.get("businesses", []):
        if "village" not in business["name"].lower():
            refined_restaurants.append({
                "name": business["name"],
                "address": ", ".join(business["location"]["display_address"]),
                "rating": business["rating"],
                "phone": business.get("display_phone", "N/A")
            })
            if len(refined_restaurants) == limit:
                break

    return refined_restaurants

# Example Usage
api_key = "ngjMz-"  # Replace with your Yelp API Key
latitude, longitude = 40.766876, -73.523663  # Coordinates of "Village - The Soul of India"

restaurants = find_similar_restaurants(api_key, latitude, longitude)
for idx, restaurant in enumerate(restaurants, start=1):
    print(f"{idx}. Restaurant: {restaurant['name']}\n   Address: {restaurant['address']}\n   Rating: {restaurant['rating']}\n   Phone: {restaurant['phone']}\n")
# Out:
# 1. Restaurant: Kunga Kitchen
#    Address: 390 Woodbury Rd, Hicksville, NY 11801
#    Rating: 4.6
#    Phone: (516) 490-5501
#
# 2. Restaurant: Taste of Mumbai
#    Address: 153 Levittown Pkwy, Hicksville, NY 11801
#    Rating: 4.6
#    Phone: (516) 261-9070
#
# 3. Restaurant: Kathis & Kababs
#    Address: 55 Broadway, Ste A, Hicksville, NY 11801
#    Rating: 4.5
#    Phone: (516) 595-7775
#
# 4. Restaurant: Kabul Grill
#    Address: 129 N Broadway, Hicksville, NY 11801
#    Rating: 4.5
#    Phone: (516) 933-8999
#
# 5. Restaurant: Taste Of Chennai
#    Address: 39 W John St, Hicksville, NY 11801
#    Rating: 4.4
#    Phone: (516) 396-1449

# %% [markdown]
# SCRAPING and DISPLAYING menu items & prices for Village + each restaurant

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager

def scrape_menu(url):
    """Scrape menu items and prices from the given restaurant URL."""
    # Setup WebDriver
    options = webdriver.ChromeOptions()
    options.add_argument('--headless')  # Run headlessly (without a UI)
    driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=options)

    try:
        # Visit the URL
        driver.get(url)

        # Optionally, wait for JavaScript to load the page if needed
        driver.implicitly_wait(5)

        # Extract Menu Item Names
        menu_items = driver.find_elements(By.CSS_SELECTOR, '.menu-item-details h4')

        # Extract Prices
        prices = driver.find_elements(By.CSS_SELECTOR, '.menu-item-price-amount')

        # Collect Data
        menu = []
        for item, price in zip(menu_items, prices):
            menu.append({
                "item": item.text,
                "price": price.text
            })
        
        return menu

    except Exception as e:
        print(f"Error occurred: {e}")
        return []

    finally:
        # Close the browser
        driver.quit()

# URLs for Village and other restaurants
restaurants = {
    "Village - The Soul of India": "https://www.yelp.com/menu/village-the-soul-of-india-hicksville",
    "Kunga Kitchen": "https://www.yelp.com/menu/kunga-kitchen-hicksville",  
    "Taste of Mumbai": "https://www.yelp.com/menu/taste-of-mumbai-hicksville-3",
    "Kathis & Kababs": "https://www.yelp.com/menu/kathis-and-kababs-hicksville", 
    "Kabul Grill": "https://www.yelp.com/menu/kabul-grill-hicksville",         
    "Taste Of Chennai": "https://www.yelp.com/menu/taste-of-chennai-hicksville" 
}

# Scrape menus for all restaurants
for restaurant, url in restaurants.items():
    print(f"\nScraping menu for {restaurant}...")
    menu = scrape_menu(url)
    if menu:
        print(f"Menu for {restaurant}:")
        for dish in menu:
            print(f"  - {dish['item']}: ${dish['price']}")
    else:
        print(f"No menu data available for {restaurant}.")
# Out:
# Scraping menu for Village - The Soul of India...
# Menu for Village - The Soul of India:
#   - Medu Vada: $$6.00
#   - Medu Vada in Sambar Bowl: $$6.99
#   - Medu Vada in Rasam Bowl: $$6.99
#   - Combo: $$5.99
#   - Combo in Sambar Bowl: $$6.99
#   - Masala Vada: $$7.45
#   - Dahi Vada: $$8.95
#   - Batata Vada: $$6.00
#   - Mysore Bonda: $$6.00
#   - Chennai Pakkoda: $$6.00
#   - Spring Rolls: $$7.45
#   - Paneer Pakkoda: $$8.95
#   - Samosa: $$6.00
#   - Aloo Tikki: $$6.00
#   - Chilly Pakora: $$6.00
#   - Tomato Soup: $$7.45
#   - Vegetables Manchow Soup: $$7.45
#   - Rasam: $$7.45
#   - Sambar: $$7.45
#   - Mulligatawny Soup: $$7.45
#   - Garden Soup: $$7.45
#   - Katchumbar Salad: $$7.45
#   - Garden Salad: $$7.45
#   - Idly: $$7.45
#   - Masala Idly: $$9.95
#   - Mini Idly: $$7.45
#   - Ghee Fried Idly: $$9.95
#   - Podi Idly: $$8.95
#   - Chilli Idly: $$9.95
#   - Idly in Sambar Bow: $$8.95
#   - Idly Rasam Bowl: $$8.95
#   - Dami Idly: $$7.45
#   - Bhel Puri: $$8.95
#   - Samosa Chat: $$8.95
#   - Aloo Tikki Chat: $$9.95
#   - Papdee Chat: $$8.95
#   - Dahi Bhalla: $$8.95
#   - Channa Chat: $$8.95
#   - Aloo Chat: $$8.95
#   - Vadda Pav: $$8.95
#   - Pav Bhaji: $$13.75
#   - Vegetables Manchurian: $$12.95
#   - Baby Corn Chilly Manchurian: $$13.75
#   - Chilly Paneer Dry: $$13.75
#   - Gobi Manchurian Dry: $$12.95
#   - Chilli Mushroom: $$12.95
#   - Crispy Chilli Potato: $$12.95
#   - Honey Garlic Gobi: $$12.95
#   - Gobi Lasuni: $$12.95
#   - Vegetables Hakka Noodles: $$13.75
#   - Vegetables Fried Rice: $$12.95
#   - Chinese Dosa: $$14.95
#   - Sada Dosa: $$11.95
#   - Set Dosa: $$11.95
#   - Masala Dosa: $$12.95
#   - Butter Sada Dosa: $$11.95
#   - Butter Masala Dosa: $$13.75
#   - Ghee Roast Masala: $$13.75
#   - Paper Roast Dosa: $$12.95
#   - Mysore Sada Dosa: $$12.95
#   - Masala Dosa: $$12.95
#   - Podi Masala Dosa: $$12.95
#   - Gun Powder Masala Dosa: $$12.95
#   - Onion Chilli Sada Dosa: $$12.95
#   - Onion Chilli Masala Dosa: $$12.95
#   - Chef Special Sampler Dosa 5 Kinds: $$24.95
#   - Chocolate Dosa: $$13.75
#   - Chocolate Dosa in Jain Fillings: $$13.75
#   - Mushroom Masala Dosa: $$13.75
#   - Jaipur Dosa: $$14.95
#   - Paneer Masala Dosa: $$14.95
#   - Paneer Bhurji Dosa: $$16.00
#   - Spinach Masala Dosa: $$14.95
#   - Cheese Onion Chili Masala Dosa: $$14.95
#   - Cheese Masala Dosa: $$13.75
#   - Cheese Masala Sada: $$13.75
#   - Spring Masala Dosa: $$14.95
#   - Pondicherry Masala Dosa: $$14.95
#   - Cheese Pondicherry: $$14.95
#   - Paneer Pondicherry Dosa: $$14.95
#   - Mushroom, Paneer, Spinach Masala Dosa: $$15.00
#   - Plain Uthappam: $$11.95
#   - Vegetable Uthappam: $$12.95
#   - Onion Chilli Uthappam: $$13.75
#   - Mushroom Uthappam: $$13.75
#   - Onion Chilli Garlic Uthappam: $$13.75
#   - Gun Powder Uthappam: $$13.75
#   - Vegetable Cheese Uthappam: $$14.95
#   - Paneer Uthappam: $$14.95
#   - Custom Uthappam: $$16.00
#   - Masala Uthappam: $$18.00
#   - Veg Uthappam: $$13.75
#   - Rava Sada Dosa: $$14.95
#   - Onion Rava Masala Dosa: $$14.95
#   - Onion Mysore Rava Masala Dosa: $$16.00
#   - Madras Rava Masala Dosa: $$16.00
#   - Cheese Onion Rava Masala Dosa: $$16.00
#   - Coconut Rava Masala Dosa: $$14.95
#   - Rava Chilli Gun Powder Masala Dosa: $$16.00
#   - Rava Chilli Gun Powder Masala Dosa in Jain Fillings: $$16.00
#   - Fresh Spring Onion Rava Masala Dosa: $$15.00
#   - Matka Dosa: $$18.00
#   - Jinni Dosa: $$18.00
#   - Village Special Dosa: $$18.00
#   - Dal Makhni: $$16.00
#   - Aloo Gobi: $$16.00
#   - Mutter: $$16.00
#   - Palak: $$16.00
#   - Gobi Mutter: $$16.00
#   - Aloo: $$16.00
#   - Chana Masala: $$16.00
#   - Chana Palak: $$16.00
#   - Daal Tadka: $$16.00
#   - Palak: $$16.00
#   - Mutter Paneer: $$16.00
#   - Palak Paneer: $$16.00
#   - Saag Paneer: $$16.00
#   - Paneer Tikka Masala: $$16.00
#   - Kadai Paneer: $$16.00
#   - Methi Mutter Malai: $$16.00
#   - Kadai Mushroom: $$16.00
#   - Malai Kofta: $$16.00
#   - Paneer Bhurji: $$16.00
#   - Bhindi Masala: $$16.00
#   - Eggplant Curry: $$16.00
#   - Baigan Bharta: $$16.00
#   - Nav Ratan Korma: $$16.00
#   - Vegetable Korma: $$16.00
#   - Alu Baingan: $$16.00
#   - Vegetables Kolhapur: $$16.00
#   - Malai Kofta Jain Style: $$16.00
#   - Poondu Kulambu: $$16.00
#   - Ennai Kathrika Kulambu: $$16.00
#   - Vendaikai Kulambu: $$14.95
#   - Murungaikai Kulambu: $$16.00
#   - Chennal Thali: $$21.95
#   - South Indian Thali: $$21.95
#   - North Indian Thali: $$21.95
#   - Chole Bature: $$16.00
#   - Chole Poori: $$16.00
#   - Poori Bhaji: $$14.95
#   - Poori Kurma: $$14.95
#   - Uppma: $$14.95
#   - Pongal: $$14.95
#   - Avial: $$14.95
#   - Kutchu Chilli Paratha: $$14.95
#   - Paneer Chettinad: $$16.00
#   - Mix Vegetables Chettinad: $$16.00
#   - Gobi Chettinad: $$16.00
#   - Soya Chettinad: $$16.00
#   - Roti: $$3.95
#   - Paratha: $$7.45
#   - Poori: $$6.00
#   - Batura: $$6.00
#   - Alu Paratha: $$8.95
#   - Onion Paratha: $$8.95
#   - Gobi Paratha: $$8.95
#   - Chilli Kuthu Paratha: $$8.95
#   - Cheese Paratha: $$8.95
#   - Paneer Paratha: $$8.95
#   - Dum Biryani: $$14.95
#   - Vegetables Pullav: $$12.95
#   - Jeera Rice: $$12.95
#   - Lemon Rice: $$12.95
#   - Tamarind Rice: $$12.95
#   - Vangi Bhath: $$12.95
#   - B.B.B Bishibila Bath: $$12.95
#   - Tomato Rice: $$12.95
#   - Coconut Rice: $$12.95
#   - Yogurt Rice: $$12.95
#   - Gulab Jamun: $$6.00
#   - Rasmalai: $$6.00
#   - Kheer: $$6.00
#   - Semiya Payasam: $$6.00
#   - Badam Halwa: $$7.45
#   - Kulfi Malai: $$6.00
#   - Halwa with Vanila Ice Cream: $$8.95
#   - Soda: $$2.95
#   - Water: $$2.95
#   - Lassi: $$6.00
#   - Madras Coffee Hot: $$2.95
#   - Masala Tea Hot: $$2.95
#   - Herbal Tea Hot: $$2.95
#   - Shake: $$6.00
#   - Fresh Lime Soda: $$7.45
#   - Masala Soda: $$7.45
#
# Scraping menu for Kunga Kitchen...
# Menu for Kunga Kitchen:
#   - CHILLI FISH DRY: $$15.59
#   - CHILLI SHRIMP DRY: $$15.59
#   - VEG SAMOSA: $$5.19
#   - VEG SPRING ROLL: $$7.27
#   - CHICKEN SPRING ROLL: $$7.27
#   - CHICKEN TIKKA: $$15.59
#   - CHICKEN SEEKH KABAB: $$13.51
#   - CAULIFLOWER MANCHURIAN DRY: $$9.35
#   - MASALA FRENCH FRIES: $$7.27
#   - CRISPY HONEY LOTUS: $$10.39
#   - VEG MANCHURIAN DRY: $$9.35
#   - CRISPY CHILLI LOTUS: $$10.39
#   - VEG STEAM DUMPLING: $$9.35
#   - CHICKEN STEAM DUMPLING: $$10.39
#   - VEG FRIED DUMPLING: $$9.35
#   - CHICKEN FRIED DUMPLING: $$10.39
#   - KAI CHI - CHICKEN WINGS: $$12.47
#   - HONEY CHICKEN DRY: $$10.39
#   - PAPAYA SALAD: $$7.27
#   - CHILLI PANEER DRY: $$10.39
#   - CHICKEN MANCHURIAN DRY: $$10.39
#   - HAKKA CHILLI CHICKEN DRY: $$11.43
#   - MANCHOW SOUP: $$2.16
#   - TOM YAM SOUP: $$2.16
#   - HOT & SOUR SOUP: $$2.16
#   - SWEET CORN SOUP: $$2.16
#   - SPICY LEMON CORIANDER SOUP: $$2.16
#   - BENGALI STYLE THAI SOUP: $$2.16
#   - BUTTER CHICKEN: $$16.63
#   - CHICKEN KORMA: $$16.63
#   - CHICKEN CURRY: $$16.63
#   - CHICKEN TIKKA MASALA: $$16.63
#   - YELLOW DAL TADKA: $$13.51
#   - PALAK PANEER: $$15.59
#   - ALOO GOBI: $$14.55
#   - CHANA MASALA: $$14.55
#   - SHRIMP TIKKA MASALA: $$20.79
#   - Shrimp Korma: $$20.79
#   - PLAIN TANDOORI ROTI: $$4.15
#   - BUTTER TANDOORI ROTI: $$4.15
#   - ONION KULCHA: $$5.19
#   - PLAIN NAAN: $$4.15
#   - BUTTER NAAN: $$4.15
#   - GARLIC NAAN: $$5.19
#   - VEG BIRYANI: $$14.55
#   - CHICKEN BIRYANI: $$16.63
#   - SHRIMP BIRYANI: $$20.79
#   - HAKKA CHILLI CHICKEN GRAVY: $$16.63
#   - SZECHUAN CHICKEN GRAVY: $$16.63
#   - YELLOW THAI CHICKEN CURRY: $$16.63
#   - RED THAI CHICKEN CURRY: $$16.63
#   - CORIANDER GARLIC CHICKEN: $$16.63
#   - CHICKEN MANCHURIAN GRAVY: $$16.63
#   - SESAME CHICKEN: $$16.63
#   - CHILLI PANEER GRAVY: $$15.59
#   - VEG MANCHURIAN GRAVY: $$15.59
#   - BLACK PEPPER CHICKEN: $$16.63
#   - VEG THAI CURRY: $$15.59
#   - CAULIFLOWER MANCHURIAN GRAVY: $$13.51
#   - CHICKEN BROCCLI: $$16.63
#   - HAKKA CHILLI SHRIMP GRAVY: $$20.79
#   - HAKKA CHILLI FISH GRAVY: $$20.79
#   - SZECHUAN SHRIMP GRAVY: $$20.79
#   - SZECHUAN FISH GRAVY: $$20.79
#   - SWEET & SOUR FISH: $$20.79
#   - SWEET & SOUR SHRIMP: $$20.79
#   - YELLOW THAI SHRIMP CURRY: $$20.79
#   - RED THAI SHRIMP CURRY: $$20.79
#   - BLACK PEPPER FISH: $$20.79
#   - BLACK PEPPER SHRIMP: $$20.79
#   - RED SNAPPER WHOLE: $$26.00
#   - Pomfret Fish: $$26.00
#   - Red Shrimp Curry: $$20.79
#   - KUNGA SPECIAL FRIED RICE: $$15.59
#   - PAD THAI NOODLES: $$12.47
#   - BURNT GARLIC FRIED RICE: $$12.47
#   - SZECHUAN FRIED RICE: $$12.47
#   - FRIED RICE: $$12.47
#   - CHILLI GARLIC FRIED RICE: $$12.47
#   - CHILLI GARLIC NOODLES: $$12.47
#   - BURNT GARLIC NOODLES: $$12.47
#   - SZECHUAN NOODLES: $$12.47
#   - HAKKA NOODLES: $$12.47
#   - Extra Plain Rice: $$5.19
#   - THAI ICED TEA: $$4.15
#   - MANGO SWEET LASSI: $$5.19
#   - GINGER LEMON HONEY: $$5.19
#   - MANGO SHAKE: $$5.19
#   - BLACK TEA: $$2.08
#   - MINT TEA: $$2.08
#   - GREEN TEA: $$2.08
#   - MASALA CHAI TEA: $$3.12
#   - BOTTLE WATER: $$2.08
#   - APPLE JUICE: $$3.64
#   - ORANGE JUICE: $$3.64
#   - BOTTLE SODA 20 Oz: $$3.64
#   - CAN SODA: $$2.08
#   - GULAB JAMUN: $$3.64
#   - KULFI: $$3.12
#   - RASMALAI: $$3.64
#   - CHILLI CHICKEN (LIGHT GRAVY): $$15.59
#   - CHICKEN TIKKA MASALA: $$15.59
#   - CHILLI PANEER (GRAVY): $$14.55
#   - Manchurian: $$14.55
#   - CHICKEN MANCHURIAN: $$15.59
#   - VEG THAI CURRY: $$14.55
#   - CHICKEN THAI CURRY: $$15.59
#   - VEG PAD THAI NOODLE: $$14.55
#   - CHICKEN PAD THAI NOODLE: $$15.59
#   - VEG FRIED RICE: $$14.55
#   - CHICKEN FRIED RICE: $$15.59
#   - VEG HAKKA NOODLE: $$14.55
#
# Scraping menu for Taste of Mumbai...
# Menu for Taste of Mumbai:
#   - Saag Paneer: $$16.99
#   - Paneer Tikka Masala: $$17.99
#   - Shahi Paneer: $$17.99
#   - Malai Kofta: $$17.99
#   - Navratan Korma: $$17.99
#   - Dal Makhni: $$16.99
#   - Mutter Paneer: $$17.99
#   - Paneer Kadai: $$17.99
#   - Methi Malai Paneer: $$18.99
#   - Manchow Soup: $$3.99
#   - Manchow Soup with Chicken: $$4.99
#   - Mulligatawny Soup: $$3.99
#   - Tomato Soup: $$3.99
#   - Kachumber Salad: $$2.99
#   - Garden Salad: $$3.99
#   - Pav Bhaji: $$6.99
#   - Papdi Chaat: $$4.99
#   - Ragada Patties: $$6.99
#   - Samosa Chaat: $$5.99
#   - Vada Pav: $$4.99
#   - Samosa Pav: $$4.99
#   - Vegetable Samosa: $$3.50
#   - Chicken Samosa: $$5.99
#   - Spring Roll: $$7.99
#   - Mumbai Veg Kathi Roll: $$7.99
#   - Bombay Chicken Kathi Roll: $$8.99
#   - Mix Pakora: $$7.99
#   - Lasuni Gobi: $$8.99
#   - Tandoori Paneer Tikka: $$11.95
#   - Chicken Tikka: $$13.99
#   - Tandoori Chicken: $$11.99
#   - Murgh Malai Kebab: $$13.99
#   - Hariyali Kebab: $$13.99
#   - Chicken Seekh Kebab: $$13.99
#   - Chicken Chops: $$11.99
#   - Chicken Drumstick: $$10.99
#   - Meat Platter: $$17.00
#   - Kashmiri Lamb Chops: $$38.00
#   - Badami Jhinga: $$13.50
#   - Shrimp Malai Kebab: $$19.99
#   - Tandoori Shrimp: $$24.50
#   - Fish Amritsari: $$10.99
#   - Tandoori Fish: $$12.99
#   - Chicken Hakka Noodles: $$10.99
#   - Chilli Paneer: $$9.99
#   - Chilli Mushroom: $$9.99
#   - Bombay Style Chili Chicken: $$10.99
#   - Chilly Chicken with Sauce: $$12.99
#   - Chicken Manchurian: $$12.99
#   - Sweet & Sour Chicken: $$12.99
#   - Coriander Garlic Chicken: $$12.99
#   - Chicken in Black Pepper Sauce: $$12.99
#   - Crispy Chili Fish: $$11.99
#   - Chili Fish with Sauce: $$12.99
#   - Sweet & Sour Fish: $$12.99
#   - Chicken Fried Rice: $$10.99
#   - Shrimp Fried Rice: $$12.99
#   - Veg Fried Rice: $$9.99
#   - Egg Fried Rice: $$10.99
#   - Veg Hakka Noodles: $$9.99
#   - Shrimp Hakka Noodles: $$12.99
#   - Egg Hakka Noodles: $$10.99
#   - Bhindi Do Pyaza: $$13.99
#   - Malai Kofta: $$13.99
#   - Paneer Aap Ki Pasand: $$13.99
#   - Saag Paneer: $$13.99
#   - Navratan Korma: $$13.99
#   - Mushroom Kadai: $$13.99
#   - Punjabi Kadhi Pakora: $$13.99
#   - Bagara Baingan: $$13.99
#   - Baingan Bharta: $$13.99
#   - Bombay Aloo Gobi: $$13.99
#   - Aloo Baingan: $$13.99
#   - Sabji Saag Malai: $$13.99
#   - Chole Peshawari: $$13.99
#   - Chole Bhature: $$13.99
#   - Sabzi Bhaji: $$13.99
#   - Mutter Paneer: $$13.99
#   - Dal Makhani: $$13.99
#   - Yellow Tadka Dal: $$13.99
#   - Daal Palak: $$13.99
#   - Chicken Vindaloo: $$15.99
#   - Chicken Tikka Masala: $$15.99
#   - Butter Chicken: $$15.99
#   - Chicken Madras: $$15.99
#   - Chicken Coconut Fry: $$15.99
#   - Milagu Kozhi Chettinad: $$15.99
#   - Kori Salan: $$15.99
#   - Green Masala Chicken: $$15.99
#   - Chicken Saag: $$15.99
#   - Murgh Shahi Korma: $$15.99
#   - Murgh Dhaniwal: $$15.99
#   - Kadai Chicken: $$15.99
#   - Methi Malai Chicken: $$15.99
#   - Chicken Curry: $$15.99
#   - Achari Chicken: $$15.99
#   - Goat Curry: $$22.99
#   - Lamb Rogan Josh: $$22.99
#   - Goat Rogan Josh: $$22.99
#   - Lamb Vindaloo: $$22.99
#   - Goat Vindaloo: $$22.99
#   - Our Choice of Phal: $$22.99
#   - Saagwala Gosht: $$22.99
#   - Coconut Fry: $$22.99
#   - Madras: $$22.99
#   - Devil: $$22.99
#   - Kobbari Chops: $$28.00
#   - Gosht Kesar Pasanda: $$22.99
#   - Mirapakaya Mamsam Koora: $$22.99
#   - Uppu Kari: $$22.99
#   - Kerala Fish Curry: $$18.99
#   - Fish Tikka Masala: $$18.99
#   - Goan Fish Curry: $$18.99
#   - Mangalorean Prawn: $$18.99
#   - Prawn Balchao: $$18.99
#   - Chicken Biryani: $$13.99
#   - Goat Biryani: $$16.99
#   - Lamb Biryani: $$16.99
#   - Shrimp Biryani: $$16.99
#   - Vegetable Biryani: $$12.99
#   - Plain Rice: $$2.99
#   - Jeera Rice: $$7.99
#   - Tandoori Roti: $$1.99
#   - Naan: $$1.99
#   - Garlic Naan: $$2.99
#   - Chili Naan: $$2.50
#   - Chapati: $$1.00
#   - Tawa Paratha: $$2.99
#   - Aloo Paratha: $$3.99
#   - Peshwari Naan: $$5.00
#   - Cheese Naan: $$5.00
#   - Keema Naan: $$5.50
#   - Onion Kulcha: $$3.99
#   - Poori: $$1.50
#   - Mix Pickle: $$1.99
#   - Raita: $$1.99
#   - Onion Chilli Lemon Salad: $$2.99
#   - Papad: $$1.99
#   - Gulab Jamun: $$4.99
#   - Ras Malai: $$4.99
#   - Carrot Halwa: $$4.99
#   - Mango Lassi: $$3.99
#   - Soft Drink: $$2.50
#   - Chikoo Shake: $$4.99
#   - Chaas: $$3.99
#   - Coffee: $$1.99
#   - Bottle Water: $$1.99
#
# Scraping menu for Kathis & Kababs...
# Menu for Kathis & Kababs:
#   - 1. Achari Aaloo Kathi Roll: $$11.95
#   - 2. Paneer Tikka Kathi Roll: $$11.95
#   - 3. Mushroom Kathi Roll: $$11.95
#   - 4. Malai Paneer Kathi Roll: $$11.95
#   - 5. Egg Omelette Kathi Roll: $$11.95
#   - 6. Chicken Tikka Kathi Roll: $$11.95
#   - 7. Chicken Malai Kathi Roll: $$11.95
#   - 8. Chicken Achari Kathi Roll: $$11.95
#   - 9. Chicken Seekh Kathi Roll: $$11.95
#   - 10. Lamb Seekh Kathi Roll: $$14.95
#   - 1. Vegetable Platter Kabab: $$14.95
#   - 2. Achari Aaloo Kabab: $$14.95
#   - 3. Paneer Tikka Kabab: $$14.95
#   - 4. Malai Paneer Tikka Kabab: $$14.95
#   - 5. Tandoori Mushroom Kabab: $$14.95
#   - 6. Chicken Tikka Kabab: $$14.95
#   - 7. Chicken Malai Tikka Kabab: $$14.95
#   - 8. Chicken Achari Tikka Kabab: $$14.95
#   - 9. Chicken Seekh Kabab: $$14.95
#   - 10. Chicken Afghani Kabab: $$17.95
#   - 11. Tandoori Chicken Kabab: $$17.95
#   - 13. Lamb Seekh Kabab: $$19.95
#   - 14. Salmon Fish Tikka Kabab: $$21.95
#   - 15. Mutton Burra Kabab: $$26.95
#   - Paneer Achari Tikka: $$14.95
#   - Tandoori Shrimp (8 pcs): $$21.95
#   - Tandoori Roti: $$2.95
#   - Butter Naan: $$3.95
#   - Garlic Naan: $$4.95
#   - Basmati Rice: $$5.95
#   - Dal Makhni (16 OZ): $$11.95
#   - Chana Masala (16 OZ): $$11.95
#   - Saag Paneer: $$11.95
#   - Bottled Water: $$1.95
#   - Soda: $$2.95
#   - Indian Soda: $$3.95
#   - Mango Lassi: $$5.95
#   - Achari Aloo Vegetarian Rice Bowl: $$12.95
#   - Malai Paneer Vegetarian Rice Bowl: $$12.95
#   - Paneer Tikka Vegetarian Rice Bowl: $$12.95
#   - Chicken Tikka Rice Bowl: $$12.95
#   - Chicken Malai Tikka Rice Bowl: $$12.95
#   - Chicken Achari Rice Bowl: $$12.95
#   - Lamb Seekh Kabab Rice Bowl: $$15.95
#   - Masala Fries: $$6.95
#   - Amritsari Fish: $$11.95
#   - Chicken Momos: $$11.95
#   - Vegetable Momos: $$10.95
#   - Chicken Wings: $$10.95
#   - Vegetable Spring Roll: $$8.95
#   - Chicken Spring Roll: $$9.95
#   - Vegetable Momos: $$10.95
#   - Gobhi Manchurian (Dry): $$12.95
#   - Vegetable Manchurian- Dry (8pcs): $$13.95
#   - Chicken Manchurian- Dry (8 pcs): $$14.95
#   - Paneer Chilli - Dry: $$14.95
#   - Chicken Chilli - Dry: $$14.95
#   - Chicken Lollipop (6 pcs): $$14.95
#   - Chicken Drumsticks (6 pcs): $$14.95
#   - Gulab Jamun: $$5.95
#   - Rasmalai: $$5.95
#   - Kheer: $$5.95
#
# Scraping menu for Kabul Grill...
# Menu for Kabul Grill:
#   - Sampler Platter: $$17.50
#   - Kadoo Bulanee: $$8.00
#   - Awshak: $$7.00
#   - Mantoo: $$7.00
#   - Sambosa: $$7.00
#   - Buranee Badenjan: $$8.00
#   - Bulanee: $$5.50
#   - Spinach Sambosa: $$5.50
#   - Bulanee Gandana: $$5.50
#   - Kashk Badenjan: $$8.00
#   - Hommus: $$6.00
#   - Chicken Wings: $$10.00
#   - Kabul Grill Special Salad: $$10.00
#   - Salad Shirazi: $$10.00
#   - House Salad: $$3.00
#   - Chicken Soup: $$6.00
#   - Aush: $$6.95
#   - Khoresht Ghimeh Stew: $$18.00
#   - Sabzi Palak Stew: $$18.00
#   - Lawand Stew: $$19.00
#   - Vegetarian Dish: $$18.95
#   - Lamb Curry: $$20.95
#   - Chicken Curry: $$19.95
#   - Combo 3: $$89.00
#   - Combo 2: $$61.00
#   - Combo 1: $$25.00
#   - Combo 4: $$79.00
#   - Lamb Chops: $$30.00
#   - Sultani Kabob: $$26.00
#   - Barg Kabob: $$22.00
#   - Chicken Breast Kabob: $$16.95
#   - Jujeh Kabob: $$20.00
#   - Kobideh Kabob: $$19.95
#   - Tikka Kabob: $$18.95
#   - Chaplee Kabob: $$19.95
#   - Falafel: $$16.95
#   - Lamb Shank Special: $$30.00
#   - Shrimp Kabob Special: $$24.95
#   - Salmon Kabob Special: $$24.95
#   - Tilapia Fillet Special: $$19.95
#   - BADENJAN CHALOU: $$20.95
#   - BAMIA CHALOU: $$23.95
#   - KADOO CHALOU: $$23.95
#   - AUSH-E-BIREDA: $$20.95
#   - Bakh Lava: $$5.50
#   - Firnee: $$6.00
#   - Lemonade: $$5.50
#   - Homemade Iced Tea: $$5.50
#   - Doogh: $$4.00
#   - Soda: $$3.00
#   - Seltzer: $$3.00
#   - Chicken Breast Kabob Lunch Special: $$19.99
#   - Chicken Kobideh Kabob Lunch Special: $$19.99
#   - Chicken Chaplee Kabob Lunch Special: $$19.99
#
# Scraping menu for Taste Of Chennai...
# Menu for Taste Of Chennai:
#   - Sambar: $$6.49
#   - Rasam: $$6.49
#   - Chicken Soup: $$8.99
#   - Punjabi Samosa (2 pcs): $$5.99
#   - Onion Pakora: $$7.99
#   - Cut Mirchi (6 pcs): $$6.99
#   - Lasuni Gobi: $$10.99
#   - Chili Paneer: $$11.99
#   - Medhu Vada (2 pcs): $$6.99
#   - Idli (2 pcs): $$6.99
#   - Mini Idli (10 pcs): $$7.99
#   - Samosa Chaat: $$8.99
#   - Papri Chaat: $$8.49
#   - Garden Salad: $$6.99
#   - Chicken Samosa (2 pcs): $$10.99
#   - Chili Chicken: $$13.99
#   - TASMAC Omelet: $$11.99
#   - Egg Roast: $$11.99
#   - Chicken 65: $$13.99
#   - Raju Gari Kodi Vepudu: $$14.99
#   - Singapore Chicken Lollipop: $$15.99
#   - Mamsam Roast: $$17.99
#   - Chili Garlic Shrimp: $$18.99
#   - Meen Pollichathu (6 pcs): $$18.99
#   - Paneer Tikka: $$16.99
#   - Malai Kabab: $$18.99
#   - Seekh Kabab: $$17.99
#   - Chicken Tikka: $$18.99
#   - Tandoori Chicken Lollipop: $$18.99
#   - Tandoori Chicken: $$19.99
#   - Tandoori Mixed Platter: $$22.99
#   - Tandoori Whole Pomfret: $$21.99
#   - Tandoori Salmon (Fish Tikka): $$25.99
#   - Tandoori Shrimp: $$22.99
#   - Lamb Chops: $$30.99
#   - Tandoori Whole Chicken: $$26.99
#   - Tandoori Whole Chicken (THANKSGIVING SPECIAL): $$29.99
#   - Plain Parotta with Korma: $$11.99
#   - Veg Kothu Parotta: $$12.99
#   - Egg Kothu Parotta: $$14.99
#   - Chicken Kothu Parotta: $$15.99
#   - Mutton Kothu Parotta: $$16.99
#   - Veg Noodles: $$11.99
#   - Egg Noodles: $$13.99
#   - Chicken Noodles: $$14.99
#   - Shrimp Noodles: $$16.99
#   - Shrimp Chicken Noodles: $$17.99
#   - Veg Fried Rice: $$11.99
#   - Egg Fried Rice: $$13.99
#   - Chicken Fried Rice: $$14.99
#   - Shrimp Fried Rice: $$16.99
#   - Shrimp Chicken Fried Rice: $$17.99
#   - Plain Dosa: $$9.99
#   - Set Dosa: $$9.99
#   - Set Egg Dosa: $$10.99
#   - Masala Dosa: $$10.99
#   - Ghee Roast: $$10.99
#   - Ghee Masala Dosa: $$11.99
#   - Cheese Dosa: $$10.99
#   - Chocolate Dosa: $$8.99
#   - Onion Uttapam: $$10.99
#   - Veg Uttapam: $$11.99
#   - Mysore Masala: $$11.99
#   - Pondicherry Masala: $$13.99
#   - Cheese Pondicherry Masala: $$14.99
#   - TOC Special Dosa: $$14.99
#   - Yellow Dal: $$11.49
#   - Aloo Gobi Masala: $$14.49
#   - Paneer Tikka Masala: $$14.99
#   - Palak Paneer: $$14.99
#   - Kadai Paneer: $$14.99
#   - Chole Pesawary: $$13.99
#   - Puli Kuzhambu: $$14.49
#   - Salem Vegetable Korma: $$14.49
#   - Bhindi Masala Curry: $$14.49
#   - Mirchi Ka Salan: $$14.49
#   - Chicken Badam Korma: $$15.99
#   - Chicken Saagwala: $$15.99
#   - Chicken Tikka Masala: $$16.99
#   - Chettinadu Curry: $$15.99
#   - Andhra Curry: $$15.99
#   - Gongura Curry: $$15.99
#   - Kadai Chicken: $$15.99
#   - Kothambar Chicken Curry: $$15.99
#   - Meen Kuzhambu: $$16.99
#   - Mangalore Shrimp Curry: $$18.99
#   - Kongunadu Chicken Curry: $$15.99
#   - Egg Curry: $$15.99
#   - Crab Masala Curry: $$21.99
#   - Veg Dum Biriyani: $$15.99
#   - Chicken Dum Biriyani: $$17.99
#   - Special Chicken Dum Biriyani: $$19.99
#   - Mutton Dum Biryani: $$19.99
#   - TOC Yellow Dal Thali (Veg): $$14.99
#   - TOC Paneer Tikka Masala Thali (Veg): $$15.99
#   - TOC Chicken Thali (Non-Veg): $$16.99
#   - TOC Mutton Thali (Non-Veg): $$17.99
#   - TOC Fish Thali (Non-Veg): $$17.99
#   - TOC Shrimp Thali (Non-Veg): $$18.99
#   - Plain Naan: $$1.99
#   - Butter Naan: $$2.99
#   - Garlic Naan: $$2.99
#   - Onion Kulcha: $$3.99
#   - Aloo Paratha: $$4.99
#   - Bullet (Chili) Naan: $$2.99
#   - Chapati: $$3.99
#   - Paratha: $$4.99
#   - Roti: $$2.99
#   - Kashmir Naan: $$2.99
#   - Plain Basmati Rice: $$1.49
#   - Plain Yogurt: $$2.29
#   - Raita: $$2.99
#   - Pickle: $$0.99
#   - Appalam: $$1.99
#   - Chennai Masala Tea: $$2.29
#   - Black Tea: $$1.75
#   - Coffee: $$3.49
#   - Sukku Malli Kappi: $$2.49
#   - Mango Lassi: $$3.99
#   - Sweet/Salt Lassi: $$3.99
#   - Lime Soda: $$3.99
#   - Neer Moor: $$3.49
#   - Milk Shakes: $$3.99
#   - Water: $$1.49
#   - Soda: $$1.49
#   - Thumbs Up: $$2.00
#   - Fanta: $$2.00
#   - Limca: $$2.00
#   - Orange Juice: $$2.29
#   - Apple Juice: $$2.29
#   - Gulab Jamun: $$4.49
#   - Payasam: $$4.49
#   - Kesari: $$4.49
#   - Rasmalai: $$4.99
#   - Badam Halwa: $$4.99
#   - Halwa a la Mode: $$5.99
#   - Kulfi: $$2.99
#   - Ice Cream: $$2.99
